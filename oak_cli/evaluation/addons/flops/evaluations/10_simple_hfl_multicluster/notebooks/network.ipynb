# %% [markdown]
# # Network

# %% [markdown]
# ---

# %%
from oak_cli.evaluation.addons.flops.utils.imports import *

# %%
prepare_notebook()

# %%
df, normalized_df, singular_run_df, trained_model_df = load_and_prepare_data(multi_cluster=True)

# %% [markdown]
# ---

# %%
draw_network_linegraph(normalized_df)

# %%
draw_network_received_linegraph(normalized_data=normalized_df, multi_cluster=True)

# %%
draw_network_send_linegraph(normalized_data=normalized_df, multi_cluster=True)

# %%
draw_mb_per_second_graph(
    data=df,
    use_bar_plot=True,
    key=NETWORK_LAST_RECEIVED_KEY,
    y_label="Network Received (MB/s)",
    y_lim=0,
)

# %%
draw_box_violin_plot_for_each_stage_for_network_received(df, multi_cluster=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 draw_box_violin_plot_for_each_stage_for_network_received(df, multi_cluster=True)
#
# NameError: name 'draw_box_violin_plot_for_each_stage_for_network_received' is not defined

# %%
draw_mb_per_second_graph(
    data=df,
    use_bar_plot=True,
    key=NETWORK_LAST_SENT_KEY,
    y_label="Network Sent (MB/s)",
    y_lim=0,
)

# %%
draw_box_violin_plot_for_each_stage_for_network_sent(df, multi_cluster=True)
