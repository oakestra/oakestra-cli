# %% [markdown]
# # Explanatory

# %% [markdown]
# ---

# %%
from oak_cli.evaluation.addons.flops.utils.imports import *

# %%
prepare_notebook()

# %%
df, normalized_df, singular_run_df, trained_model_df = load_and_prepare_data()

# %% [markdown]
# ---

# %%
draw_line_graph_with_all_runs(
    data=df,
    y_label="Memory Usage (%)",
    key=MEMORY_KEY,
    )

# %%
draw_graph(
    title="Evaluation Runs Average",
    data=df[[CPU_KEY, MEMORY_KEY, STAGE_KEY]], # type: ignore
    use_percentage_limits=True,
    y_label="Resource Usage (%)",
    show_stages=True,
    stages_color_intensity=0.01,
)
