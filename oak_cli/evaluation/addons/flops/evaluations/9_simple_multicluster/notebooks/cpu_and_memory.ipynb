# %% [markdown]
# # CPU & Memory

# %% [markdown]
# ---

# %%
from oak_cli.evaluation.addons.flops.utils.imports import *

# %%
prepare_notebook()

# %%
df, normalized_df, singular_run_df, trained_model_df = load_and_prepare_data(multi_cluster=True)

# %% [markdown]
# ---

# %%
draw_cpu_and_memory_linegraph(normalized_df)

# %%
draw_cpu_linegraph(normalized_data=normalized_df, multi_cluster=True)

# %%
draw_memory_linegraph(normalized_data=normalized_df, multi_cluster=True)

# %%
draw_box_violin_plot_for_each_stage_for_cpu(df, multi_cluster=True)

# %%
sns.boxplot(
                x=CPU_KEY,
                #y=STAGE_KEY,
                y=NODE_KEY,
                data=normalized_df,
                hue=STAGE_KEY,
                #hue=NODE_KEY,
                #alpha=0.3,
                #palette=stage_color_map,
            ),
# Out:
# (<Axes: xlabel='CPU Usage', ylabel='Node'>,)

# %%
draw_box_violin_plot_for_each_stage_for_cpu(df)

# %%
draw_box_violin_plot_for_each_stage_for_memory(df, x_lim=0)
