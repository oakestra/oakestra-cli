# %% [markdown]
# # Network

# %% [markdown]
# ---

# %%
from oak_cli.evaluation.addons.flops.utils.imports import *

# %%
prepare_notebook()

# %%
df, normalized_df, singular_run_df, trained_model_df = load_and_prepare_data()

# %% [markdown]
# ---

# %%
import re

res = normalized_df[IO_COUNTERS_KEY].iloc[0]
res = res.replace('"', "'")
# Remove leading/trailing spaces and escape single quotes inside the string
cleaned_string = res.strip().replace("'", "\\'").replace(' ', '')

# Regular expression pattern to match keys and values
pattern = r'"(.*?)"\s*:\s*snetio\(.*?\)'

# Find matches
matches = re.findall(pattern, cleaned_string)

# Construct the dictionary
dictionary = {}
for match in matches:
    key = match.split(':')[0].strip()
    value = 'snetio(...)  # Placeholder for actual value parsing
    dictionary[key] = value

print(dictionary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 5
#       3 import json
#       4 import ast
# ----> 5 res = ast.literal_eval(res)
#       6 #res = json.dumps(res)
#       7 print((type(res), res))
#
# File ~/miniconda3/envs/alex/lib/python3.10/ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~/miniconda3/envs/alex/lib/python3.10/ast.py:99, in literal_eval.<locals>._convert(node)
#      97     if len(node.keys) != len(node.values):
#      98         _raise_malformed_node(node)
# ---> 99     return dict(zip(map(_convert, node.keys),
#     100                     map(_convert, node.values)))
#     101 elif isinstance(node, BinOp) and isinstance(node.op, (Add, Sub)):
#     102     left = _convert_signed_num(node.left)
#
# ...

# %%
draw_network_linegraph(normalized_df)

# %%
draw_mb_per_second_graph(
    data=df,
    use_bar_plot=True,
    key=NETWORK_LAST_RECEIVED_KEY,
    y_label="Network Received (MB/s)",
    y_lim=0,
)

# %%
draw_box_violin_plot_for_each_stage_for_network_received(df)

# %%
draw_mb_per_second_graph(
    data=df,
    use_bar_plot=True,
    key=NETWORK_LAST_SENT_KEY,
    y_label="Network Sent (MB/s)",
    y_lim=0,
)

# %%
draw_box_violin_plot_for_each_stage_for_network_sent(df)
