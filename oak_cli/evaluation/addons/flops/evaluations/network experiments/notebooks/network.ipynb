# %% [markdown]
# # Network

# %% [markdown]
# ---

# %%
from oak_cli.evaluation.addons.flops.utils.imports import *

# %%
prepare_notebook()

# %%
df, normalized_df, singular_run_df, trained_model_df = load_and_prepare_data()

# %% [markdown]
# ---

# %%
draw_network_linegraph_dumdum(singular_run_df)

# %%
key = ResourcesCSVKeys.NETWORK_RECEIVED_SINCE_START__lo.value

sns.lineplot(
    data=normalized_df[[key] + [STAGE_KEY, RUN_ID_KEY]],
    x=TIME_START_KEY,
    y=key,
    hue=RUN_ID_KEY,
    )
# Out:
# <Axes: xlabel='Time Since Evaluation-Run Start', ylabel='Network Received Since Start lo'>

# %%
draw_network_linegraph_dumdum(normalized_df)

# %%
draw_network_linegraph(singular_run_df)

# %%
draw_network_linegraph(normalized_df)

# %%
draw_mb_per_second_graph(
    data=df,
    use_bar_plot=True,
    key=NETWORK_LAST_RECEIVED_KEY,
    y_label="Network Received (MB/s)",
    y_lim=0,
)

# %%
draw_box_violin_plot_for_each_stage_for_network_received(df)

# %%
draw_mb_per_second_graph(
    data=df,
    use_bar_plot=True,
    key=NETWORK_LAST_SENT_KEY,
    y_label="Network Sent (MB/s)",
    y_lim=0,
)

# %%
draw_box_violin_plot_for_each_stage_for_network_sent(df)
