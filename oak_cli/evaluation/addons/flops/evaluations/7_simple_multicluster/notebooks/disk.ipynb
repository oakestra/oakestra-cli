# %% [markdown]
# # Disk Space

# %% [markdown]
# ---

# %%
from oak_cli.evaluation.addons.flops.utils.imports import *

# %%
prepare_notebook()

# %%
df, normalized_df, singular_run_df, trained_model_df = load_and_prepare_data(multi_cluster=True)

# %% [markdown]
# ---

# %%
draw_disk_space_linegraph(normalized_data=normalized_df)

# %%
draw_disk_space_linegraph(normalized_data=normalized_df, multi_cluster=True)
